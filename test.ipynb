# %%
from helper_modules.visualAgent import generate_code,get_fig_from_code
from helper_modules.agent import query
import re
user_input="generate a distribution plot"

    

response=generate_code(user_input)
code_block_match=re.search(r'```(?:[Pp]ython)?(.*?)```',response,re.DOTALL)

if code_block_match:
    code_block=code_block_match.group(1).strip()
    cleaned_code=re.sub(r'(?m)^\s*fig\.show\(\)\s*$','',code_block)
    # print(cleaned_code)
    fig= get_fig_from_code(cleaned_code)
    

fig

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set matplotlib to use an interactive backend
plt.switch_backend('TkAgg')

# Load the data from the CSV file
data = pd.read_csv('helper_modules/test.csv')

# Create a scatter plot using seaborn
plt.figure(figsize=(10, 6))
sns.scatterplot(x='math score', y='reading score', data=data)

# Add labels and title
plt.title('Scatter Plot of Math Score vs Reading Score')
plt.xlabel('Math Score')
plt.ylabel('Reading Score')

# Show the plot
plt.show()

# %%
import pandas as pd
df=pd.read_csv("data\IMDB Dataset.csv")

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("data/IMDB Dataset.csv")

# Save only the first 100 rows
df.head(100).to_csv("data/IMDB_Dataset.csv", index=False)

print("Saved the first 100 rows successfully!")
# Out:
# Saved the first 100 rows successfully!

# %%
import pandas as pd
import plotly.express as px
from collections import Counter
import re
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('helper_modules/test.csv')

# Combine all reviews into a single string
text = ' '.join(df['review'].tolist())

# Remove HTML tags
clean_text = re.sub(r'<.*?>', '', text)

# Convert to lowercase
clean_text = clean_text.lower()

# Split into words
words = re.findall(r'\b\w+\b', clean_text)

# Get stopwords
stop_words = set(stopwords.words('english'))

# Filter out stopwords
filtered_words = [word for word in words if word not in stop_words]

# Count word frequencies
word_counts = Counter(filtered_words)

# Generate word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_counts)

# Plot word cloud with matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of Reviews')
plt.show()
